# %% [markdown]
# <a href="https://colab.research.google.com/github/Yasidrzp/Pembelajaran_mesin/blob/main/Tugas2_Pembelajaran_Mesin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = '/content/dataset.csv'
df = pd.read_csv('/content/dataset.csv')
df
# Out:
#      Tahun       Kabupaten  Jumlah
# 0     2014           Buton   96634
# 1     2014            Muna  208916
# 2     2014          Konawe  229801
# 3     2014          Kolaka  235652
# 4     2014  Konawe Selatan  289815
# ..     ...             ...     ...
# 165   2023      Muna Barat   89290
# 166   2023    Buton Tengah  119460
# 167   2023   Buton Selatan   99580
# 168   2023    Kota Kendari  364220
# 169   2023     Kota Baubau  166150
#
# [170 rows x 3 columns]

# %%
# Membuat Heatmap
plt.figure(figsize=(10, 6))
heatmap_df = df.pivot('Kabupaten', 'Tahun', 'Jumlah')
sns.heatmap(heatmap_df, cmap='YlGnBu', annot=True, fmt='d', linewidths=.5)
plt.title('Populasi Kabupaten Sulawesi Tenggara (2014-2023)')
plt.xlabel('Tahun')
plt.ylabel('Kabupaten')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-3-f3f4b871c613>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   heatmap_df = df.pivot('Kabupaten', 'Tahun', 'Jumlah')

# %% [markdown]
# Visualisasi Heatmap di atas menunjukkan bahwa populasi di Sulawesi Tenggara meningkat secara keseluruhan dalam beberapa tahun terakhir. Kota Kendari menjadi daerah dengan populasi terbanyak, sedangkan Konawe Kepulauan menjadi daerah dengan populasi terendah.
# Sementara itu, Kabupaten Konawe menjadi daerah dengan populasi yang pesat. Sedangkan Kabupaten Muna menjadi daerah dengan populasi yang relatif stabil.
